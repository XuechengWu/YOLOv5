# %% [markdown]
# # 1. Allgemein Setup
# > * In Windows CMD einmalig schreiben:
# > 1. cd nach YOLO_v5_Masterarbeit Ordner
# > 2. pip install --user -r requirements.txt

# %%
# In Windows CMD schreiben:
# 1. cd YOLO_v5_Masterarbeit
# 2. pip install --user -r requirements.txt

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5  2022-5-31 Python-3.8.10 torch-1.12.1+cpu CPU
# Setup complete  (4 CPUs, 3.5 GB RAM, 304.2/365.5 GB disk)

# %% [markdown]
# # 2. Hardware Bestätigung
# > Wenn die Output von "torch.cuda.is_available()" False ist, braucht man cuda noch einmal installieren.

# %%
# nvidia-smi
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# # 3. detect.py laufen
# Ergebnis wird in `runs/detect` gespeichert.
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# import os

# detect_command = 'python detect.py --weights best300epoches.pt --img 640 --conf 0.5'
# a = os.popen(detect_command)
# b = a.read()
# print(b)
